# %%
# 🏥 Day 4: Redshift Basics + HIPAA Understanding + Project Simulation

# === 1. Setup ===
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# Load Cleaned CMS Data

# %%
file_path = r'C:\Users\shazi\Healthcare_Project\output\state_readmission_summary.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Quick Preview

# %%
df.head()
# Out:
#   state  count_of_readm_measures_worse
# 0    AK                            4.0
# 1    AL                           45.0
# 2    AR                           39.0
# 3    AS                            0.0
# 4    AZ                           39.0

# %% [markdown]
# Simulate Redshift Query (Group by state)

# %%
state_summary = df.groupby('state')['count_of_readm_measures_worse'].sum().reset_index()

# %% [markdown]
# Preview Result

# %%
print(state_summary.head())
# Out:
#   state  count_of_readm_measures_worse
# 0    AK                            4.0
# 1    AL                           45.0
# 2    AR                           39.0
# 3    AS                            0.0
# 4    AZ                           39.0

# %% [markdown]
# Visualization (Simulated Redshift Output)

# %%
plt.figure(figsize=(14, 7))
sns.barplot(data=state_summary.sort_values('count_of_readm_measures_worse', ascending=False),
            x='state', y='count_of_readm_measures_worse', palette='coolwarm')

plt.title('Simulated Redshift: Readmission Measures by State', fontsize=16)
plt.xticks(rotation=45)
plt.ylabel('Count of Worse Readmission Measures')
plt.xlabel('State')
plt.tight_layout()
plt.savefig(r'C:\Users\shazi\Healthcare_Project\output\day4_redshift_simulation.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\shazi\AppData\Local\Temp\ipykernel_37940\1309566414.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=state_summary.sort_values('count_of_readm_measures_worse', ascending=False),

# %% [markdown]
# Save visual

# %%
plt.savefig(r'C:\Users\shazi\Healthcare_Project\output\day4_redshift_simulation.png', dpi=300, bbox_inches='tight')

# %%
print("""
HIPAA Basics:
- HIPAA = Health Insurance Portability and Accountability Act
- Primary goal: Protect patient data privacy
- Covers Protected Health Information (PHI)
- Analysts must ensure data is anonymized, securely stored, and accessed by authorized personnel only
- Critical for handling healthcare datasets like CMS
""")
# Out:
# HIPAA Basics:
# - HIPAA = Health Insurance Portability and Accountability Act
# - Primary goal: Protect patient data privacy
# - Covers Protected Health Information (PHI)
# - Analysts must ensure data is anonymized, securely stored, and accessed by authorized personnel only
# - Critical for handling healthcare datasets like CMS
